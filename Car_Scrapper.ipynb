# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

BaseUrl = '/www.cars.com/shopping/results/?'

# Function that prepares the URL with the parameters given by the client
def Preparator(BaseUrl, MaxPrice, MinPrice, brand, status):
    Url = BaseUrl + 'dealer_id=&keyword=&list_price_max=%s&list_price_min=%s&makes[]=%s&maximum_distance=30&mileage_max=&monthly_payment=3289&page_size=20&sort=best_match_desc&stock_type=%s&year_max=&year_min=&zip=60606' % (MaxPrice, MinPrice, brand, status)
    print(Url)
    return Url

AllCarsOutput = []

# Function to get the Cars' data, one by one and then store each one of them in the "AllCarsOutput" variable
def GetData(Url):
    url = Url
    while True:
        Req = requests.get('http:/' + url).text
        Soup = BeautifulSoup(Req, 'html.parser')
        CarList = Soup.find_all('div', class_='vehicle-details')
        PageBtns = Soup.find_all('a', class_='sds-button sds-button--secondary sds-pagination__control')
        print(PageBtns)
        NextPageBtn = []
        for i in PageBtns:
            if i['aria-label'] == 'Next page':
                NextPageBtn = i
                break
            else:
                pass
        for i in range(len(CarList)):
            CarListOutput = {
                'Title': CarList[i].find('h2', class_='title').text,
                'Price': CarList[i].find('span', class_='primary-price').text,
                'Stock-Type': CarList[i].find('p', class_ = 'stock-type').text,
            }
            AllCarsOutput.append(CarListOutput)
            print(CarListOutput)
            print(NextPageBtn)
        if NextPageBtn:
            url = '/www.cars.com' + NextPageBtn['href']
            pass
        else:
            break


# Function to export all the retrieved data into an .xls file
def SaveData(OP):
    df = pd.DataFrame(OP, columns=['Title', 'Price', 'Stock-Type'])
    df.to_excel('Cars List.xls', index=True, columns=['Title', 'Price', 'Stock-Type'])

# Run the whole process given certain parameters
FUrl = Preparator(BaseUrl, 175000, 2000, 'hyundai', 'all')
GetData(FUrl)
SaveData(AllCarsOutput)
# Out:
# /www.cars.com/shopping/results/?dealer_id=&keyword=&list_price_max=175000&list_price_min=2000&makes[]=hyundai&maximum_distance=30&mileage_max=&monthly_payment=3289&page_size=20&sort=best_match_desc&stock_type=all&year_max=&year_min=&zip=60606
# [<a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=2&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="2">Next</a>]
# {'Title': '2023 Hyundai Santa Cruz SEL Premium AWD', 'Price': '$38,879', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=2&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="2">Next</a>
# {'Title': '2023 Hyundai Santa Fe SEL', 'Price': '$33,615', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=2&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="2">Next</a>
# {'Title': '2023 Hyundai Santa Fe SEL', 'Price': '$37,598', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=2&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="2">Next</a>
# {'Title': '2023 Hyundai Venue SEL', 'Price': '$23,295', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=2&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="2">Next</a>
# {'Title': '2023 Hyundai Santa Cruz SEL Premium AWD', 'Price': '$38,705', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=2&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="2">Next</a>
# {'Title': '2023 Hyundai Santa Cruz SEL', 'Price': '$29,795', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=2&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="2">Next</a>
# {'Title': '2023 Hyundai Elantra HEV Blue', 'Price': '$26,150', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=2&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="2">Next</a>
# {'Title': '2021 Hyundai Tucson SEL', 'Price': '$24,777', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=2&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="2">Next</a>
# {'Title': '2017 Hyundai Accent SE', 'Price': '$8,999', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=2&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="2">Next</a>
# {'Title': '2019 Hyundai Santa Fe XL Limited Ultimate', 'Price': '$25,500', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=2&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="2">Next</a>
# {'Title': '2023 Hyundai Tucson SE', 'Price': '$30,320', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=2&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="2">Next</a>
# {'Title': '2023 Hyundai Santa Fe SEL', 'Price': '$35,835', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=2&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="2">Next</a>
# {'Title': '2023 Hyundai Tucson SEL', 'Price': '$31,700', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=2&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="2">Next</a>
# {'Title': '2015 Hyundai Santa Fe Sport 2.4L', 'Price': '$17,699', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=2&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="2">Next</a>
# {'Title': '2023 Hyundai Santa Cruz 2.5T SEL Premium', 'Price': '$35,900', 'Stock-Type': 'Hyundai Certified'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=2&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="2">Next</a>
# {'Title': '2023 Hyundai IONIQ 5 SEL', 'Price': '$48,770', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=2&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="2">Next</a>
# {'Title': '2023 Hyundai IONIQ 5 SEL', 'Price': '$48,890', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=2&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="2">Next</a>
# {'Title': '2014 Hyundai Elantra SE', 'Price': '$9,277', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=2&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="2">Next</a>
# {'Title': '2021 Hyundai Kona EV SEL', 'Price': '$25,000', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=2&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="2">Next</a>
# {'Title': '2016 Hyundai Sonata Limited', 'Price': '$18,404', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=2&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="2">Next</a>
# [<a aria-label="Previous page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=1&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="prev_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="1">Prev</a>, <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=3&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="3">Next</a>]
# {'Title': '2019 Hyundai Elantra SE', 'Price': '$19,256', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=3&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="3">Next</a>
# {'Title': '2023 Hyundai Palisade Calligraphy', 'Price': '$54,300', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=3&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="3">Next</a>
# {'Title': '2023 Hyundai Santa Cruz SEL Premium AWD', 'Price': '$38,795', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=3&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="3">Next</a>
# {'Title': '2023 Hyundai Palisade Calligraphy', 'Price': '$53,860', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=3&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="3">Next</a>
# {'Title': '2023 Hyundai Palisade XRT', 'Price': '$45,615', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=3&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="3">Next</a>
# {'Title': '2023 Hyundai Santa Fe SEL', 'Price': '$35,438', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=3&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="3">Next</a>
# {'Title': '2023 Hyundai Sonata Hybrid SEL', 'Price': '$33,170', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=3&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="3">Next</a>
# {'Title': '2023 Hyundai Sonata Hybrid SEL', 'Price': '$33,170', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=3&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="3">Next</a>
# {'Title': '2023 Hyundai Elantra N Base', 'Price': '$35,710', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=3&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="3">Next</a>
# {'Title': '2023 Hyundai Palisade Calligraphy', 'Price': '$53,085', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=3&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="3">Next</a>
# {'Title': '2023 Hyundai Tucson SEL', 'Price': '$31,940', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=3&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="3">Next</a>
# {'Title': '2023 Hyundai Kona SEL', 'Price': '$25,820', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=3&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="3">Next</a>
# {'Title': '2023 Hyundai Santa Cruz SE AWD', 'Price': '$29,170', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=3&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="3">Next</a>
# {'Title': '2023 Hyundai Kona SEL', 'Price': '$24,934', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=3&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="3">Next</a>
# {'Title': '2023 Hyundai IONIQ 5 SEL', 'Price': '$47,880', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=3&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="3">Next</a>
# {'Title': '2023 Hyundai Elantra Limited', 'Price': '$27,446', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=3&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="3">Next</a>
# {'Title': '2023 Hyundai Elantra N Line', 'Price': '$28,088', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=3&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="3">Next</a>
# {'Title': '2023 Hyundai Elantra HEV Limited', 'Price': '$30,910', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=3&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="3">Next</a>
# {'Title': '2023 Hyundai Santa Cruz SEL', 'Price': '$34,805', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=3&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="3">Next</a>
# {'Title': '2022 Hyundai Santa Fe Plug-In Hybrid SEL Convenience', 'Price': '$36,319', 'Stock-Type': 'Hyundai Certified'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=3&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="3">Next</a>
# {'Title': '2023 Hyundai IONIQ 5 Limited', 'Price': '$59,700', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=3&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="3">Next</a>
# [<a aria-label="Previous page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=2&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="prev_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="2">Prev</a>, <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=4&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="4">Next</a>]
# {'Title': '2023 Hyundai Palisade Calligraphy', 'Price': '$53,865', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=4&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="4">Next</a>
# {'Title': '2023 Hyundai Elantra N Line', 'Price': '$28,331', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=4&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="4">Next</a>
# {'Title': '2023 Hyundai Venue Limited', 'Price': '$24,795', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=4&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="4">Next</a>
# {'Title': '2023 Hyundai Santa Cruz 2.5T NIGHT', 'Price': '$38,085', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=4&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="4">Next</a>
# {'Title': '2023 Hyundai Sonata Hybrid SEL', 'Price': '$33,200', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=4&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="4">Next</a>
# {'Title': '2023 Hyundai Sonata SE', 'Price': '$25,895', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=4&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="4">Next</a>
# {'Title': '2023 Hyundai Santa Cruz 2.5T SEL Premium', 'Price': '$36,533', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=4&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="4">Next</a>
# {'Title': '2023 Hyundai Santa Fe SEL', 'Price': '$39,905', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=4&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="4">Next</a>
# {'Title': '2023 Hyundai Santa Cruz SEL AWD', 'Price': '$30,735', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=4&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="4">Next</a>
# {'Title': '2023 Hyundai Elantra N Line', 'Price': '$28,050', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=4&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="4">Next</a>
# {'Title': '2023 Hyundai Elantra Limited', 'Price': '$28,130', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=4&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="4">Next</a>
# {'Title': '2020 Hyundai Veloster N N', 'Price': '$26,490', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=4&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="4">Next</a>
# {'Title': '2023 Hyundai Tucson Limited', 'Price': '$39,651', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=4&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="4">Next</a>
# {'Title': '2023 Hyundai Elantra Limited', 'Price': '$27,850', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=4&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="4">Next</a>
# {'Title': '2022 Hyundai Sonata Hybrid Limited', 'Price': '$34,273', 'Stock-Type': 'Hyundai Certified'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=4&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="4">Next</a>
# {'Title': '2023 Hyundai IONIQ 5 SEL', 'Price': '$48,330', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=4&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="4">Next</a>
# {'Title': '2023 Hyundai Tucson Hybrid SEL Convenience', 'Price': '$36,255', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=4&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="4">Next</a>
# {'Title': '2023 Hyundai Venue Limited', 'Price': '$24,815', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=4&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="4">Next</a>
# {'Title': '2023 Hyundai Venue Limited', 'Price': '$24,820', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=4&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="4">Next</a>
# {'Title': '2021 Hyundai Santa Fe HEV Blue', 'Price': '$29,785', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=4&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="4">Next</a>
# [<a aria-label="Previous page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=3&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="prev_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="3">Prev</a>, <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=5&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="5">Next</a>]
# {'Title': '2017 Hyundai Tucson Night', 'Price': '$19,977', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=5&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="5">Next</a>
# {'Title': '2017 Hyundai Sonata Hybrid Limited', 'Price': '$17,985', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=5&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="5">Next</a>
# {'Title': '2023 Hyundai Sonata SEL Plus', 'Price': '$33,845', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=5&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="5">Next</a>
# {'Title': '2023 Hyundai Santa Fe Limited', 'Price': '$43,809', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=5&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="5">Next</a>
# {'Title': '2023 Hyundai Sonata SEL Plus', 'Price': '$32,856', 'Stock-Type': 'New'}
# ...
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=94&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="94">Next</a>
# {'Title': '2016 Hyundai Sonata Sport', 'Price': '$11,530', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=94&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="94">Next</a>
# {'Title': '2018 Hyundai Santa Fe Sport 2.4L', 'Price': '$14,800', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=94&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="94">Next</a>
# {'Title': '2020 Hyundai Kona SEL', 'Price': '$21,995', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=94&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="94">Next</a>
# {'Title': '2018 Hyundai Elantra SEL', 'Price': '$20,995', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=94&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="94">Next</a>
# {'Title': '2022 Hyundai Sonata SEL Plus', 'Price': '$32,995', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=94&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="94">Next</a>
# {'Title': '2017 Hyundai Tucson Sport', 'Price': '$15,286', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=94&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="94">Next</a>
# [<a aria-label="Previous page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=93&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="prev_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="93">Prev</a>, <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=95&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="95">Next</a>]
# {'Title': '2019 Hyundai Tucson Value', 'Price': '$22,218', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=95&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="95">Next</a>
# {'Title': '2022 Hyundai Tucson Limited', 'Price': '$33,842', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=95&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="95">Next</a>
# {'Title': '2020 Hyundai Kona Ultimate', 'Price': '$24,995', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=95&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="95">Next</a>
# {'Title': '2021 Hyundai Palisade Limited', 'Price': '$44,691', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=95&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="95">Next</a>
# {'Title': '2023 Hyundai Palisade SEL', 'Price': '$48,270', 'Stock-Type': 'New'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=95&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="95">Next</a>
# {'Title': '2014 Hyundai Santa Fe Sport 2.0L Turbo', 'Price': '$16,726', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=95&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="95">Next</a>
# {'Title': '2021 Hyundai Santa Fe Limited', 'Price': '$32,973', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=95&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="95">Next</a>
# {'Title': '2015 Hyundai Sonata Limited 2.0T', 'Price': '$15,997', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=95&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="95">Next</a>
# {'Title': '2017 Hyundai Tucson Night', 'Price': '$19,977', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=95&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="95">Next</a>
# {'Title': '2019 Hyundai Santa Fe Ultimate 2.4', 'Price': '$24,989', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=95&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="95">Next</a>
# {'Title': '2019 Hyundai Tucson Value', 'Price': '$19,902', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=95&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="95">Next</a>
# {'Title': '2011 Hyundai Sonata SE 2.0T', 'Price': '$7,900', 'Stock-Type': 'Used'}
# <a aria-label="Next page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=95&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="next_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="95">Next</a>
# [<a aria-label="Previous page" class="sds-button sds-button--secondary sds-pagination__control" data-liveview-pageview-click="true" data-prevent-default="true" data-scroll-behavior="auto" href="/shopping/results/?page=94&amp;page_size=20&amp;dealer_id=&amp;keyword=&amp;list_price_max=175000&amp;list_price_min=2000&amp;makes[]=hyundai&amp;maximum_distance=30&amp;mileage_max=&amp;monthly_payment=3289&amp;sort=best_match_desc&amp;stock_type=all&amp;year_max=&amp;year_min=&amp;zip=60606" id="prev_paginate" phx-click="page_clicked" phx-hook="ScrollToTopOnClick" phx-value-page="94">Prev</a>]
# {'Title': '2019 Hyundai Accent SE', 'Price': '$9,171', 'Stock-Type': 'Used'}
# []
# {'Title': '2021 Hyundai Santa Fe Limited', 'Price': '$32,239', 'Stock-Type': 'Hyundai Certified'}
# []
# {'Title': '2019 Hyundai Elantra SE', 'Price': '$16,390', 'Stock-Type': 'Hyundai Certified'}
# []
# {'Title': '2018 Hyundai Tucson SEL', 'Price': '$14,695', 'Stock-Type': 'Used'}
# []
# {'Title': '2019 Hyundai IONIQ Hybrid Blue', 'Price': '$18,390', 'Stock-Type': 'Used'}
# []
# {'Title': '2021 Hyundai Venue SE', 'Price': '$18,490', 'Stock-Type': 'Hyundai Certified'}
# []
# {'Title': '2020 Hyundai IONIQ Hybrid SEL', 'Price': '$21,490', 'Stock-Type': 'Hyundai Certified'}
# []
# {'Title': '2021 Hyundai Palisade Limited', 'Price': '$44,500', 'Stock-Type': 'Hyundai Certified'}
# []
# {'Title': '2023 Hyundai Santa Fe Limited', 'Price': '$42,000', 'Stock-Type': 'Hyundai Certified'}
# []
# {'Title': '2022 Hyundai Santa Fe SEL', 'Price': '$26,990', 'Stock-Type': 'Hyundai Certified'}
# []
# C:\Users\OIA2EC~1.ORI\AppData\Local\Temp/ipykernel_5000/618872654.py:50: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df.to_excel('Cars List.xls', index=True, columns=['Title', 'Price', 'Stock-Type'])
